# %% [markdown]
# # Thai Vowel Classification — CNN + MFCC
#
# **Model:** CNN (Conv2D × 3 → BatchNorm → Dropout → Dense)
#
# **Input:** MFCC + delta + delta²
#
# **Evaluation:** 10% held-out test set → Stratified 5-fold CV on remaining 90%
#
# **Preprocessing:** smart_crop() (peak-energy 500 ms window)

# %% [markdown]
# ## Section 1 — Setup

# %%
import os
import random
import numpy as np
import pandas as pd
import librosa
import tensorflow as tf
import matplotlib.font_manager as fm
import urllib.request
from pydub import AudioSegment
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Mounted at /content/drive

# %%
# ── Constants ───────────────────────────────────────────────
SR          = 16000
HOP_LENGTH  = 512
N_FFT       = 2048
N_CLASSES   = 18
EPOCHS      = 100
BATCH_SIZE  = 32
RANDOM_SEED = 42
N_FOLDS     = 5

VOWEL_LABELS = [
    'อา','อี','อือ','อู','เอ','แอ','โอ','ออ','เออ',
    'อะ','อิ','อึ','อุ','เอะ','แอะ','โอะ','เอาะ','เออะ'
]

# ── Fix Random Seed ─────────────────────────────────────────
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print(f'Random seed fixed: {RANDOM_SEED}')
# Out:
# Random seed fixed: 42

# %% [markdown]
# ## Section 2 — Load Dataset

# %%
base_path = r'/content/drive/My Drive/dataset'

data = []
for label in os.listdir(base_path):
    folder = os.path.join(base_path, label)
    if os.path.isdir(folder):
        for file in os.listdir(folder):
            if file.endswith('.wav'):
                data.append([os.path.join(folder, file), label])

df = pd.DataFrame(data, columns=['file_path', 'label'])
print(f'Total samples : {len(df)}')
print(df['label'].value_counts())
# Out:
# Total samples : 1800
# label
# s4    100
# s7    100
# s8    100
# s9    100
# s2    100
# s6    100
# s5    100
# s3    100
# s1    100
# 09    100
# 08    100
# 06    100
# 07    100
# 03    100
# 05    100
# 04    100
# 02    100
# 01    100
# Name: count, dtype: int64

# %% [markdown]
# ## Section 3 — Preprocessing Functions

# %%
def detect_leading_silence(sound, silence_threshold=-30.0, chunk_size=10):
    """Trim silence from both ends."""
    trim_ms = 0
    while trim_ms < len(sound) and sound[trim_ms:trim_ms+chunk_size].dBFS < silence_threshold:
        trim_ms += chunk_size
    return trim_ms


def smart_crop(file_path, output_dir, window_ms=500, silence_threshold=-30.0):
    """
    Peak-energy crop: trim silence → find frame with max RMS energy
    → crop window_ms centred on that peak.
    Replaces the old fixed 25-50-25 crop.
    """
    os.makedirs(output_dir, exist_ok=True)
    sound = AudioSegment.from_file(file_path)

    start = detect_leading_silence(sound, silence_threshold)
    end   = detect_leading_silence(sound.reverse(), silence_threshold)
    trimmed = sound[start : len(sound) - end]

    if len(trimmed) == 0:
        trimmed = sound

    chunk_ms  = 10
    energies  = [trimmed[i:i+chunk_ms].rms for i in range(0, len(trimmed), chunk_ms)]
    peak_idx  = int(np.argmax(energies))
    peak_ms   = peak_idx * chunk_ms

    half       = window_ms // 2
    crop_start = max(0, peak_ms - half)
    crop_end   = min(len(trimmed), crop_start + window_ms)
    final      = trimmed[crop_start:crop_end]

    out_path = os.path.join(output_dir, f'sc_{os.path.basename(file_path)}')
    final.export(out_path, format='wav')
    return out_path

# %% [markdown]
# ## Section 4 — Feature Extraction (MFCC + delta + delta²)

# %%
def extract_mfcc(file_path, n_mfcc=20, max_len=18):
    """
    Extract MFCC + delta + delta² → shape (n_mfcc*3, max_len).
    Per-sample normalization for stable training.
    """
    wave, _ = librosa.load(file_path, mono=True, sr=SR)

    mfcc = librosa.feature.mfcc(y=wave, sr=SR, n_mfcc=n_mfcc,
                                  n_fft=N_FFT, hop_length=HOP_LENGTH)
    if mfcc.shape[1] < 9:
        mfcc = np.pad(mfcc, ((0,0),(0, 9 - mfcc.shape[1])), mode='edge')

    delta  = librosa.feature.delta(mfcc, mode='nearest')
    delta2 = librosa.feature.delta(mfcc, order=2, mode='nearest')
    feat   = np.vstack([mfcc, delta, delta2])  # (n_mfcc*3, T)

    if feat.shape[1] < max_len:
        feat = np.pad(feat, ((0,0),(0, max_len - feat.shape[1])), mode='constant')
    else:
        feat = feat[:, :max_len]

    # Per-sample normalization → stable gradient across all folds
    feat = (feat - feat.mean()) / (feat.std() + 1e-6)

    return feat  # (n_mfcc*3, max_len)

# %%
# ── Debug: ดู range ก่อน/หลัง normalize จากไฟล์ตัวอย่าง ──
sample_path = df['file_path'].iloc[0]
wave, _ = librosa.load(sample_path, mono=True, sr=SR)
mfcc = librosa.feature.mfcc(y=wave, sr=SR, n_mfcc=20, n_fft=N_FFT, hop_length=HOP_LENGTH)
delta = librosa.feature.delta(mfcc, mode='nearest')
delta2 = librosa.feature.delta(mfcc, order=2, mode='nearest')
feat_raw = np.vstack([mfcc, delta, delta2])

print('── ก่อน normalize ──')
print(f'  Max: {feat_raw.max():.4f}  Min: {feat_raw.min():.4f}')
print(f'  Mean: {feat_raw.mean():.4f}  Std: {feat_raw.std():.4f}')

feat_norm = (feat_raw - feat_raw.mean()) / (feat_raw.std() + 1e-6)

print('\n── หลัง normalize ──')
print(f'  Max: {feat_norm.max():.4f}  Min: {feat_norm.min():.4f}')
print(f'  Mean: {feat_norm.mean():.4f}  Std: {feat_norm.std():.4f}')
# Out:
# ── ก่อน normalize ──
#   Max: 142.4043  Min: -136.5668
#   Mean: -1.0318  Std: 26.9962
#
# ── หลัง normalize ──
#   Max: 5.3132  Min: -5.0205
#   Mean: 0.0000  Std: 1.0000
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1953
#   warnings.warn(

# %% [markdown]
# ## Section 5 — Dataset Analysis (duration percentiles)
#
# Run once to justify MAX_LEN choice.

# %%
durations = []
for fp in tqdm(df['file_path'], desc='Measuring durations'):
    y, _ = librosa.load(fp, sr=SR)
    durations.append(len(y) / SR)

durations = np.array(durations)
print('Duration stats (seconds):')
for p in [25, 50, 75, 90, 95]:
    frames = int(np.percentile(durations, p) * SR / HOP_LENGTH)
    print(f'  p{p}: {np.percentile(durations, p):.3f}s → {frames} frames')
# Out:
# Measuring durations: 100%|██████████| 1800/1800 [07:17<00:00,  4.12it/s]
# Duration stats (seconds):
#   p25: 0.123s → 3 frames
#   p50: 0.226s → 7 frames
#   p75: 0.375s → 11 frames
#   p90: 0.491s → 15 frames
#   p95: 0.576s → 18 frames

# %% [markdown]
# ## Section 6 — Build Full Dataset

# %%
PROC_DIR = '/content/proc_smartcrop'
N_MFCC   = 20
MAX_LEN  = 18  # p95 from duration analysis

processed_paths = [
    smart_crop(fp, PROC_DIR)
    for fp in tqdm(df['file_path'], desc='smart_crop')
]

X = np.array([
    extract_mfcc(p, n_mfcc=N_MFCC, max_len=MAX_LEN)
    for p in tqdm(processed_paths, desc='MFCC extraction')
])  # (N, n_mfcc*3, MAX_LEN)

le    = LabelEncoder()
y_int = le.fit_transform(df['label'])

print(f'X shape : {X.shape}')
print(f'Classes : {le.classes_}')
# Out:
# smart_crop: 100%|██████████| 1800/1800 [00:07<00:00, 250.28it/s]
# MFCC extraction:   0%|          | 0/1800 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1952
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1776
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1440
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1808
#   warnings.warn(
# MFCC extraction:   0%|          | 7/1800 [00:00<00:30, 58.51it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1472
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1552
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2000
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1600
#   warnings.warn(
# MFCC extraction:   1%|          | 13/1800 [00:00<00:35, 50.01it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1712
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1648
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1840
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1504
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1968
#   warnings.warn(
# MFCC extraction:   1%|          | 19/1800 [00:00<00:34, 51.19it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1488
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1872
#   warnings.warn(
# MFCC extraction:   1%|▏         | 25/1800 [00:00<00:33, 53.69it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1856
#   warnings.warn(
# MFCC extraction:   2%|▏         | 31/1800 [00:00<00:32, 53.85it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1936
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1536
#   warnings.warn(
# MFCC extraction:   2%|▏         | 40/1800 [00:00<00:27, 63.06it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1760
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1728
#   warnings.warn(
# MFCC extraction:   3%|▎         | 47/1800 [00:00<00:27, 62.61it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1312
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1584
#   warnings.warn(
# MFCC extraction:   3%|▎         | 58/1800 [00:00<00:23, 74.40it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1520
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=992
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1664
#   warnings.warn(
# MFCC extraction:   4%|▍         | 68/1800 [00:01<00:21, 78.75it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1696
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1280
#   warnings.warn(
# MFCC extraction:   4%|▍         | 76/1800 [00:01<00:22, 77.06it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=976
#   warnings.warn(
# MFCC extraction:   5%|▍         | 84/1800 [00:01<00:22, 77.53it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1296
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1616
#   warnings.warn(
# MFCC extraction:   5%|▌         | 92/1800 [00:01<00:23, 71.69it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1984
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1824
#   warnings.warn(
# MFCC extraction:   6%|▌         | 100/1800 [00:01<00:24, 70.43it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1744
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1680
#   warnings.warn(
# MFCC extraction:   7%|▋         | 118/1800 [00:01<00:21, 78.63it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2016
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1072
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1376
#   warnings.warn(
# MFCC extraction:   7%|▋         | 126/1800 [00:01<00:24, 69.05it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1392
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1920
#   warnings.warn(
# MFCC extraction:   7%|▋         | 134/1800 [00:01<00:23, 70.82it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1792
#   warnings.warn(
# MFCC extraction:   8%|▊         | 142/1800 [00:02<00:26, 62.37it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1888
#   warnings.warn(
# MFCC extraction:   8%|▊         | 149/1800 [00:02<00:27, 61.10it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1568
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1904
#   warnings.warn(
# MFCC extraction:   9%|▉         | 159/1800 [00:02<00:23, 70.32it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1136
#   warnings.warn(
# MFCC extraction:  11%|█▏        | 206/1800 [00:02<00:18, 83.96it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1200
#   warnings.warn(
# MFCC extraction:  12%|█▏        | 215/1800 [00:02<00:18, 83.64it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1168
#   warnings.warn(
# MFCC extraction:  13%|█▎        | 237/1800 [00:03<00:16, 96.20it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2032
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1248
#   warnings.warn(
# MFCC extraction:  15%|█▍        | 263/1800 [00:03<00:13, 110.53it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1456
#   warnings.warn(
# MFCC extraction:  15%|█▌        | 276/1800 [00:03<00:13, 113.15it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1328
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1104
#   warnings.warn(
# MFCC extraction:  21%|██▏       | 384/1800 [00:04<00:10, 130.88it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1632
#   warnings.warn(
# MFCC extraction:  22%|██▏       | 398/1800 [00:04<00:10, 128.93it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1264
#   warnings.warn(
# MFCC extraction:  23%|██▎       | 411/1800 [00:04<00:11, 124.63it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1408
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1152
#   warnings.warn(
# MFCC extraction:  24%|██▎       | 424/1800 [00:04<00:11, 121.89it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1424
#   warnings.warn(
# MFCC extraction:  24%|██▍       | 437/1800 [00:04<00:11, 122.09it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=912
#   warnings.warn(
# MFCC extraction:  27%|██▋       | 479/1800 [00:05<00:10, 129.05it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1008
#   warnings.warn(
# MFCC extraction:  28%|██▊       | 505/1800 [00:05<00:10, 128.96it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1344
#   warnings.warn(
# MFCC extraction:  32%|███▏      | 584/1800 [00:05<00:09, 124.86it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1360
#   warnings.warn(
# MFCC extraction:  38%|███▊      | 677/1800 [00:06<00:09, 123.13it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1056
#   warnings.warn(
# MFCC extraction:  40%|███▉      | 718/1800 [00:07<00:08, 126.54it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1184
#   warnings.warn(
# MFCC extraction:  41%|████      | 731/1800 [00:07<00:08, 125.12it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1216
#   warnings.warn(
# MFCC extraction:  44%|████▍     | 798/1800 [00:07<00:07, 129.16it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1040
#   warnings.warn(
# MFCC extraction:  45%|████▌     | 811/1800 [00:07<00:07, 128.23it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=944
#   warnings.warn(
# MFCC extraction:  47%|████▋     | 850/1800 [00:08<00:07, 125.57it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1232
#   warnings.warn(
# MFCC extraction: 100%|██████████| 1800/1800 [00:19<00:00, 91.94it/s]
# X shape : (1800, 60, 18)
# Classes : ['01' '02' '03' '04' '05' '06' '07' '08' '09' 's1' 's2' 's3' 's4' 's5'
#  's6' 's7' 's8' 's9']

# %% [markdown]
# ## Section 7 — Hold-Out Test Split (10%)

# %%
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_int,
    test_size=0.10,
    random_state=RANDOM_SEED,
    stratify=y_int
)

print(f'Train+Val : {X_trainval.shape[0]} samples')
print(f'Test      : {X_test.shape[0]} samples  ← ไม่แตะจนกว่าจะ train final model เสร็จ')
# Out:
# Train+Val : 1620 samples
# Test      : 180 samples  ← ไม่แตะจนกว่าจะ train final model เสร็จ

# %% [markdown]
# ## Section 8 — Model Architecture (CNN)

# %%
def build_model(input_shape):
    """
    CNN for 2-D feature map.
    Input shape: (n_features, max_len, 1)
    """
    model = models.Sequential([
        layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=input_shape),
        # layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        # layers.Dropout(0.25),

        layers.Conv2D(64, (3,3), activation='relu', padding='same'),
        layers.Flatten(),# og not have flatten
        # layers.BatchNormalization(),
        # layers.MaxPooling2D((2,2)),
        # layers.Dropout(0.25),

        # layers.Conv2D(128, (3,3), activation='relu', padding='same'),
        # layers.BatchNormalization(),
        # layers.GlobalAveragePooling2D(),
        # layers.Dropout(0.3),

        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(N_CLASSES, activation='softmax'),
    ])
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

dummy = build_model((X_trainval.shape[1], X_trainval.shape[2], 1))
dummy.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 60, 18, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 30, 9, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 30, 9, 64)      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 17280)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     1,105,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 18)             │         1,170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,125,970 (4.30 MB)
#  Trainable params: 1,125,970 (4.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Section 9 — Stratified 5-Fold Cross-Validation

# %%
skf          = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_SEED)
fold_results = []

X_tv = X_trainval[..., np.newaxis]  # add channel dim

for fold, (tr_idx, val_idx) in enumerate(skf.split(X_trainval, y_trainval), 1):
    print(f'\n── Fold {fold}/{N_FOLDS} ──')

    random.seed(RANDOM_SEED * fold)
    np.random.seed(RANDOM_SEED * fold)
    tf.random.set_seed(RANDOM_SEED * fold)

    X_tr,  X_val  = X_tv[tr_idx],      X_tv[val_idx]
    y_tr,  y_val  = y_trainval[tr_idx], y_trainval[val_idx]

    y_tr_cat  = to_categorical(y_tr,  N_CLASSES)
    y_val_cat = to_categorical(y_val, N_CLASSES)

    model = build_model(X_tr.shape[1:])
    es    = EarlyStopping(monitor='val_loss', patience=15,
                          restore_best_weights=True, verbose=0)

    model.fit(
        X_tr, y_tr_cat,
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        validation_data=(X_val, y_val_cat),
        callbacks=[es], verbose=0
    )


    val_loss, val_acc_eval = model.evaluate(X_val, y_val_cat, verbose=0)
    train_loss, train_acc_eval = model.evaluate(X_tr, y_tr_cat, verbose=0)

    y_pred = np.argmax(model.predict(X_val, verbose=0), axis=1)
    f1     = f1_score(y_val, y_pred, average='macro')
    acc    = np.mean(y_pred == y_val)

    fold_results.append({
        'fold': fold,
        'val_acc': acc,
        'val_f1_macro': f1,
        'val_loss': val_loss,
        'train_loss': train_loss,
    })
    print(f'  Val Acc: {acc*100:.2f}%   Macro F1: {f1:.4f}   Val Loss: {val_loss:.4f}   Train Loss: {train_loss:.4f}')

df_folds = pd.DataFrame(fold_results)
print('\n' + '='*55)
print('  CV Summary')
print('='*55)
print(f"  Val Acc    : {df_folds['val_acc'].mean()*100:.2f}% ± {df_folds['val_acc'].std()*100:.2f}%")
print(f"  Macro F1   : {df_folds['val_f1_macro'].mean():.4f} ± {df_folds['val_f1_macro'].std():.4f}")
print(f"  Val Loss   : {df_folds['val_loss'].mean():.4f} ± {df_folds['val_loss'].std():.4f}")
print(f"  Train Loss : {df_folds['train_loss'].mean():.4f} ± {df_folds['train_loss'].std():.4f}")
print('='*55)
# Out:
# ── Fold 1/5 ──
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Val Acc: 89.81%   Macro F1: 0.8978   Val Loss: 0.3041   Train Loss: 0.0527
#
# ── Fold 2/5 ──
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Val Acc: 86.73%   Macro F1: 0.8670   Val Loss: 0.3502   Train Loss: 0.0727
#
# ── Fold 3/5 ──
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Val Acc: 89.51%   Macro F1: 0.8952   Val Loss: 0.2920   Train Loss: 0.0391
#
# ── Fold 4/5 ──
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Val Acc: 89.81%   Macro F1: 0.8980   Val Loss: 0.3275   Train Loss: 0.0695
#
# ── Fold 5/5 ──
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#   Val Acc: 91.36%   Macro F1: 0.9128   Val Loss: 0.3551   Train Loss: 0.0557
#
# =======================================================
#   CV Summary
# =======================================================
#   Val Acc    : 89.44% ± 1.68%
#   Macro F1   : 0.8941 ± 0.0167
#   Val Loss   : 0.3258 ± 0.0277
#   Train Loss : 0.0580 ± 0.0136
# =======================================================

# %% [markdown]
# ## Section 10 — Train Final Model

# %%
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

X_tv_final = X_trainval[..., np.newaxis]
y_tv_cat   = to_categorical(y_trainval, N_CLASSES)

X_tf, X_vf, y_tf, y_vf = train_test_split(
    X_tv_final, y_tv_cat, test_size=0.1,
    random_state=RANDOM_SEED, stratify=y_trainval
)

final_model = build_model(X_tf.shape[1:])
es_final    = EarlyStopping(monitor='val_loss', patience=15,
                             restore_best_weights=True, verbose=1)

history = final_model.fit(
    X_tf, y_tf,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    validation_data=(X_vf, y_vf),
    callbacks=[es_final], verbose=1
)
print('Final model trained.')
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 6s 108ms/step - accuracy: 0.2339 - loss: 2.4285 - val_accuracy: 0.5432 - val_loss: 1.6193
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.4396 - loss: 1.7058 - val_accuracy: 0.7654 - val_loss: 1.0514
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.5617 - loss: 1.3205 - val_accuracy: 0.8025 - val_loss: 0.7978
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.6214 - loss: 1.1444 - val_accuracy: 0.8025 - val_loss: 0.6586
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.6687 - loss: 0.9608 - val_accuracy: 0.8333 - val_loss: 0.6126
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7181 - loss: 0.8369 - val_accuracy: 0.8272 - val_loss: 0.5527
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.7428 - loss: 0.7504 - val_accuracy: 0.8642 - val_loss: 0.5410
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7689 - loss: 0.7203 - val_accuracy: 0.8395 - val_loss: 0.5318
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7627 - loss: 0.6516 - val_accuracy: 0.8580 - val_loss: 0.4986
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.7833 - loss: 0.5923 - val_accuracy: 0.8765 - val_loss: 0.4815
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.7970 - loss: 0.5785 - val_accuracy: 0.8580 - val_loss: 0.5612
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.8086 - loss: 0.5329 - val_accuracy: 0.8765 - val_loss: 0.5486
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8347 - loss: 0.4678 - val_accuracy: 0.8704 - val_loss: 0.4816
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.8388 - loss: 0.4611 - val_accuracy: 0.8642 - val_loss: 0.5023
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8704 - loss: 0.3856 - val_accuracy: 0.8827 - val_loss: 0.4967
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.8587 - loss: 0.3838 - val_accuracy: 0.8889 - val_loss: 0.4732
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.8628 - loss: 0.4056 - val_accuracy: 0.8827 - val_loss: 0.5730
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 0.8868 - loss: 0.3458 - val_accuracy: 0.8827 - val_loss: 0.5167
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8861 - loss: 0.3258 - val_accuracy: 0.8951 - val_loss: 0.4991
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8820 - loss: 0.3232 - val_accuracy: 0.9136 - val_loss: 0.4575
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8841 - loss: 0.3060 - val_accuracy: 0.9074 - val_loss: 0.4899
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step - accuracy: 0.8944 - loss: 0.2995 - val_accuracy: 0.9012 - val_loss: 0.4529
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.8964 - loss: 0.2900 - val_accuracy: 0.8951 - val_loss: 0.4951
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.8951 - loss: 0.2688 - val_accuracy: 0.9012 - val_loss: 0.4420
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8957 - loss: 0.2802 - val_accuracy: 0.9012 - val_loss: 0.5436
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9081 - loss: 0.2468 - val_accuracy: 0.9012 - val_loss: 0.5453
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9177 - loss: 0.2317 - val_accuracy: 0.9012 - val_loss: 0.5306
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9026 - loss: 0.2458 - val_accuracy: 0.9074 - val_loss: 0.5308
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9102 - loss: 0.2508 - val_accuracy: 0.9136 - val_loss: 0.5308
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9012 - loss: 0.2564 - val_accuracy: 0.8827 - val_loss: 0.5572
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.9198 - loss: 0.2140 - val_accuracy: 0.9012 - val_loss: 0.5982
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9033 - loss: 0.2447 - val_accuracy: 0.9012 - val_loss: 0.5444
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.9053 - loss: 0.2305 - val_accuracy: 0.8827 - val_loss: 0.6736
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - accuracy: 0.9211 - loss: 0.2186 - val_accuracy: 0.9012 - val_loss: 0.5636
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9204 - loss: 0.2182 - val_accuracy: 0.9074 - val_loss: 0.5681
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9211 - loss: 0.2038 - val_accuracy: 0.9136 - val_loss: 0.6134
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9355 - loss: 0.1716 - val_accuracy: 0.8951 - val_loss: 0.6788
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9369 - loss: 0.1729 - val_accuracy: 0.9074 - val_loss: 0.5000
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.9246 - loss: 0.1921 - val_accuracy: 0.9074 - val_loss: 0.5106
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Final model trained.

# %% [markdown]
# ## Section 11 — Evaluate on Held-Out Test Set

# %%
X_te        = X_test[..., np.newaxis]
y_pred_test = np.argmax(final_model.predict(X_te, verbose=0), axis=1)

test_acc = np.mean(y_pred_test == y_test)
test_f1  = f1_score(y_test, y_pred_test, average='macro')

print('='*45)
print('  FINAL TEST RESULTS (CNN + MFCC)')
print('='*45)
print(f'  Test Accuracy : {test_acc*100:.2f}%')
print(f'  Macro F1      : {test_f1:.4f}')
print('='*45)
print('\nClassification Report:')
print(classification_report(y_test, y_pred_test, target_names=VOWEL_LABELS))
# Out:
# =============================================
#   FINAL TEST RESULTS (CNN + MFCC)
# =============================================
#   Test Accuracy : 90.00%
#   Macro F1      : 0.9008
# =============================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           อา       1.00      0.90      0.95        10
#           อี       1.00      0.80      0.89        10
#          อือ       0.82      0.90      0.86        10
#           อู       0.77      1.00      0.87        10
#           เอ       0.82      0.90      0.86        10
#           แอ       1.00      1.00      1.00        10
#           โอ       0.89      0.80      0.84        10
#           ออ       1.00      0.90      0.95        10
#          เออ       1.00      0.90      0.95        10
#           อะ       0.89      0.80      0.84        10
#           อิ       0.83      1.00      0.91        10
#           อึ       0.75      0.90      0.82        10
#           อุ       1.00      0.80      0.89        10
#          เอะ       0.80      0.80      0.80        10
#          แอะ       1.00      1.00      1.00        10
#          โอะ       0.80      0.80      0.80        10
#         เอาะ       1.00      1.00      1.00        10
#         เออะ       1.00      1.00      1.00        10
#
#     accuracy                           0.90       180
#    macro avg       0.91      0.90      0.90       180
# weighted avg       0.91      0.90      0.90       180

# %% [markdown]
# ## Section 12 — Confusion Matrix

# %%
# ── Thai font setup ─────────────────────────────────────────
urllib.request.urlretrieve(
    'https://github.com/google/fonts/raw/main/ofl/sarabun/Sarabun-Regular.ttf',
    '/content/Sarabun-Regular.ttf'
)
fm.fontManager.addfont('/content/Sarabun-Regular.ttf')
plt.rcParams['font.family'] = 'Sarabun'
print('Thai font loaded.')
# Out:
# Thai font loaded.

# %%
cm = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=VOWEL_LABELS, yticklabels=VOWEL_LABELS)
plt.title('Confusion Matrix — CNN + MFCC', fontsize=14)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/exp_cnn_mfcc_cm.png', dpi=150)
plt.show()

# %% [markdown]
# ## Section 13 — Training Curve

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['accuracy'],     label='Train')
axes[0].plot(history.history['val_accuracy'], label='Val')
axes[0].set_title('Accuracy')
axes[0].legend()

axes[1].plot(history.history['loss'],     label='Train')
axes[1].plot(history.history['val_loss'], label='Val')
axes[1].set_title('Loss')
axes[1].legend()

plt.suptitle('Training Curve — CNN + MFCC')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/exp_cnn_mfcc_curve.png', dpi=150)
plt.show()

# %% [markdown]
# ## Section 14 — Save Model & Results

# %%
# final_model.save('/content/drive/MyDrive/exp_cnn_mfcc_model.h5')
# print('Model saved: exp_cnn_mfcc_model.h5')

# df_folds.to_csv('/content/drive/MyDrive/exp_cnn_mfcc_cv.csv', index=False)

print('\n── For comparison table ──')
print(f"CNN + MFCC | CV F1: {df_folds['val_f1_macro'].mean():.4f}±{df_folds['val_f1_macro'].std():.4f} | Test F1: {test_f1:.4f} | Test Acc: {test_acc*100:.2f}%")
# Out:
# ── For comparison table ──
# CNN + MFCC | CV F1: 0.8941±0.0167 | Test F1: 0.9008 | Test Acc: 90.00%
