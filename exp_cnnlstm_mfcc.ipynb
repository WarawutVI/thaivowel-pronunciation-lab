# %% [markdown]
# # Thai Vowel Classification — CNN+LSTM + MFCC

# %% [markdown]
# ## Section 1 — Setup

# %%
import os
import random
import numpy as np
import pandas as pd
import librosa
import tensorflow as tf
import matplotlib.font_manager as fm
import urllib.request
from pydub import AudioSegment
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Mounted at /content/drive

# %%
# ── Constants ───────────────────────────────────────────────
SR          = 16000
HOP_LENGTH  = 512
N_FFT       = 2048
N_CLASSES   = 18
EPOCHS      = 100
BATCH_SIZE  = 32
RANDOM_SEED = 42
N_FOLDS     = 5

VOWEL_LABELS = [
    'อา','อี','อือ','อู','เอ','แอ','โอ','ออ','เออ',
    'อะ','อิ','อึ','อุ','เอะ','แอะ','โอะ','เอาะ','เออะ'
]

# ── Fix Random Seed ─────────────────────────────────────────
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
print(f'Random seed fixed: {RANDOM_SEED}')
# Out:
# Random seed fixed: 42

# %% [markdown]
# ## Section 2 — Load Dataset

# %%
base_path = r'/content/drive/My Drive/dataset'

data = []
for label in os.listdir(base_path):
    folder = os.path.join(base_path, label)
    if os.path.isdir(folder):
        for file in os.listdir(folder):
            if file.endswith('.wav'):
                data.append([os.path.join(folder, file), label])

df = pd.DataFrame(data, columns=['file_path', 'label'])
print(f'Total samples : {len(df)}')
print(df['label'].value_counts())
# Out:
# Total samples : 1800
# label
# s4    100
# s7    100
# s8    100
# s9    100
# s2    100
# s6    100
# s5    100
# s3    100
# s1    100
# 09    100
# 08    100
# 06    100
# 07    100
# 03    100
# 05    100
# 04    100
# 02    100
# 01    100
# Name: count, dtype: int64

# %% [markdown]
# ## Section 3 — Preprocessing Functions

# %%
def detect_leading_silence(sound, silence_threshold=-30.0, chunk_size=10):
    trim_ms = 0
    while trim_ms < len(sound) and sound[trim_ms:trim_ms+chunk_size].dBFS < silence_threshold:
        trim_ms += chunk_size
    return trim_ms


def smart_crop(file_path, output_dir, window_ms=500, silence_threshold=-30.0):
    os.makedirs(output_dir, exist_ok=True)
    sound = AudioSegment.from_file(file_path)

    start = detect_leading_silence(sound, silence_threshold)
    end   = detect_leading_silence(sound.reverse(), silence_threshold)
    trimmed = sound[start : len(sound) - end]

    if len(trimmed) == 0:
        trimmed = sound

    chunk_ms  = 10
    energies  = [trimmed[i:i+chunk_ms].rms for i in range(0, len(trimmed), chunk_ms)]
    peak_idx  = int(np.argmax(energies))
    peak_ms   = peak_idx * chunk_ms

    half       = window_ms // 2
    crop_start = max(0, peak_ms - half)
    crop_end   = min(len(trimmed), crop_start + window_ms)
    final      = trimmed[crop_start:crop_end]

    out_path = os.path.join(output_dir, f'sc_{os.path.basename(file_path)}')
    final.export(out_path, format='wav')
    return out_path

# %% [markdown]
# ## Section 4 — Feature Extraction (MFCC + delta + delta²)

# %%
def extract_mfcc(file_path, n_mfcc=20, max_len=18):
    wave, _ = librosa.load(file_path, mono=True, sr=SR)

    mfcc = librosa.feature.mfcc(y=wave, sr=SR, n_mfcc=n_mfcc,
                                  n_fft=N_FFT, hop_length=HOP_LENGTH)
    if mfcc.shape[1] < 9:
        mfcc = np.pad(mfcc, ((0,0),(0, 9 - mfcc.shape[1])), mode='edge')

    delta  = librosa.feature.delta(mfcc, mode='nearest')
    delta2 = librosa.feature.delta(mfcc, order=2, mode='nearest')
    feat   = np.vstack([mfcc, delta, delta2])  # (n_mfcc*3, T)

    if feat.shape[1] < max_len:
        feat = np.pad(feat, ((0,0),(0, max_len - feat.shape[1])), mode='constant')
    else:
        feat = feat[:, :max_len]

    # Per-sample normalization → stable gradient across all folds
    feat = (feat - feat.mean()) / (feat.std() + 1e-6)

    return feat  # (n_mfcc*3, max_len)

# %% [markdown]
# ## Section 5 — Dataset Analysis (duration percentiles)
#
# Run once to justify MAX_LEN choice.

# %%
durations = []
for fp in tqdm(df['file_path'], desc='Measuring durations'):
    y, _ = librosa.load(fp, sr=SR)
    durations.append(len(y) / SR)

durations = np.array(durations)
print('Duration stats (seconds):')
for p in [25, 50, 75, 90, 95]:
    frames = int(np.percentile(durations, p) * SR / HOP_LENGTH)
    print(f'  p{p}: {np.percentile(durations, p):.3f}s → {frames} frames')
# Out:
# Measuring durations: 100%|██████████| 1800/1800 [11:07<00:00,  2.70it/s]
# Duration stats (seconds):
#   p25: 0.123s → 3 frames
#   p50: 0.226s → 7 frames
#   p75: 0.375s → 11 frames
#   p90: 0.491s → 15 frames
#   p95: 0.576s → 18 frames

# %% [markdown]
# ## Section 6 — Build Full Dataset

# %%
PROC_DIR = '/content/proc_smartcrop'
MAX_LEN  = 18  # p95 from duration analysis

processed_paths = [
    smart_crop(fp, PROC_DIR)
    for fp in tqdm(df['file_path'], desc='smart_crop')
]

X = np.array([
    extract_mfcc(p, max_len=MAX_LEN)
    for p in tqdm(processed_paths, desc='MFCC extraction')
])  # (N, n_mfcc*3, MAX_LEN)

le    = LabelEncoder()
y_int = le.fit_transform(df['label'])

print(f'X shape : {X.shape}')
print(f'Classes : {le.classes_}')
# Out:
# smart_crop: 100%|██████████| 1800/1800 [00:05<00:00, 359.96it/s]
# MFCC extraction:   0%|          | 0/1800 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1952
#   warnings.warn(
# MFCC extraction:   0%|          | 1/1800 [00:01<35:51,  1.20s/it]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1776
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1440
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1808
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1472
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1552
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2000
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1600
#   warnings.warn(
# MFCC extraction:   1%|          | 13/1800 [00:01<02:12, 13.47it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1712
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1648
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1840
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1504
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1968
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1488
#   warnings.warn(
# MFCC extraction:   1%|          | 22/1800 [00:01<01:15, 23.51it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1872
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1856
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1936
#   warnings.warn(
# MFCC extraction:   2%|▏         | 38/1800 [00:01<00:39, 44.73it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1536
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1760
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1728
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1312
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1584
#   warnings.warn(
# MFCC extraction:   3%|▎         | 55/1800 [00:01<00:25, 67.24it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1520
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=992
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1664
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1696
#   warnings.warn(
# MFCC extraction:   4%|▍         | 73/1800 [00:01<00:19, 88.91it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1280
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=976
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1296
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1616
#   warnings.warn(
# MFCC extraction:   5%|▍         | 88/1800 [00:01<00:17, 96.76it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1984
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1824
#   warnings.warn(
# MFCC extraction:   6%|▌         | 102/1800 [00:01<00:16, 104.89it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1744
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1680
#   warnings.warn(
# MFCC extraction:   6%|▋         | 116/1800 [00:02<00:16, 102.88it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2016
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1072
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1376
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1392
#   warnings.warn(
# MFCC extraction:   7%|▋         | 129/1800 [00:02<00:15, 107.76it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1920
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1792
#   warnings.warn(
# MFCC extraction:   8%|▊         | 148/1800 [00:02<00:13, 127.02it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1888
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1568
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1904
#   warnings.warn(
# MFCC extraction:   9%|▉         | 166/1800 [00:02<00:11, 140.25it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1136
#   warnings.warn(
# MFCC extraction:  11%|█         | 197/1800 [00:02<00:12, 128.46it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1200
#   warnings.warn(
# MFCC extraction:  12%|█▏        | 214/1800 [00:02<00:11, 137.20it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1168
#   warnings.warn(
# MFCC extraction:  13%|█▎        | 230/1800 [00:02<00:11, 141.03it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2032
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1248
#   warnings.warn(
# MFCC extraction:  15%|█▍        | 263/1800 [00:03<00:10, 143.81it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1456
#   warnings.warn(
# MFCC extraction:  16%|█▌        | 280/1800 [00:03<00:10, 150.27it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1328
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1104
#   warnings.warn(
# MFCC extraction:  21%|██▏       | 386/1800 [00:03<00:08, 166.23it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1632
#   warnings.warn(
# MFCC extraction:  22%|██▏       | 403/1800 [00:04<00:09, 147.44it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1264
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1408
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1152
#   warnings.warn(
# MFCC extraction:  23%|██▎       | 422/1800 [00:04<00:08, 156.56it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1424
#   warnings.warn(
# MFCC extraction:  24%|██▍       | 440/1800 [00:04<00:08, 160.72it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=912
#   warnings.warn(
# MFCC extraction:  26%|██▋       | 474/1800 [00:04<00:08, 159.91it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1008
#   warnings.warn(
# MFCC extraction:  28%|██▊       | 507/1800 [00:04<00:08, 149.33it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1344
#   warnings.warn(
# MFCC extraction:  32%|███▏      | 572/1800 [00:05<00:08, 150.64it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1360
#   warnings.warn(
# MFCC extraction:  38%|███▊      | 680/1800 [00:06<00:08, 136.98it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1056
#   warnings.warn(
# MFCC extraction:  39%|███▉      | 705/1800 [00:06<00:06, 166.72it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1184
#   warnings.warn(
# MFCC extraction:  41%|████      | 731/1800 [00:06<00:05, 189.89it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1216
#   warnings.warn(
# MFCC extraction:  44%|████▍     | 792/1800 [00:06<00:05, 194.99it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1040
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=944
#   warnings.warn(
# MFCC extraction:  48%|████▊     | 860/1800 [00:06<00:04, 205.67it/s]/usr/local/lib/python3.12/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1232
#   warnings.warn(
# MFCC extraction: 100%|██████████| 1800/1800 [00:12<00:00, 148.45it/s]
# X shape : (1800, 60, 18)
# Classes : ['01' '02' '03' '04' '05' '06' '07' '08' '09' 's1' 's2' 's3' 's4' 's5'
#  's6' 's7' 's8' 's9']

# %% [markdown]
# ## Section 7 — Hold-Out Test Split (10%)

# %%
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y_int,
    test_size=0.10,
    random_state=RANDOM_SEED,
    stratify=y_int
)

print(f'Train+Val : {X_trainval.shape[0]} samples')
print(f'Test      : {X_test.shape[0]} samples ')
# Out:
# Train+Val : 1620 samples
# Test      : 180 samples

# %% [markdown]
# ## Section 8 — Model Architecture (CNN)

# %%
def build_model(input_shape):

    inp = layers.Input(shape=input_shape)


    x = layers.Conv2D(32, (2,2), activation='relu', padding='same')(inp)
    x = layers.MaxPooling2D((2,1))(x)
    x = layers.Conv2D(64, (2,2), activation='relu', padding='same')(x)



    x = layers.Permute((2, 1, 3))(x)
    shape = x.shape
    x = layers.Reshape((shape[1], shape[2] * shape[3]))(x)


    x = layers.LSTM(512, activation='tanh', return_sequences=True , dropout=0.35)(x)
    x = layers.LSTM(512, activation='tanh', dropout=0.35)(x)


    out = layers.Dense(N_CLASSES, activation='softmax')(x)

    model = models.Model(inp, out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

dummy = build_model((X_trainval.shape[1], X_trainval.shape[2], 1))
dummy.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)      │ (None, 60, 18, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 60, 18, 32)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 30, 18, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 30, 18, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute_7 (Permute)             │ (None, 18, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_7 (Reshape)             │ (None, 18, 1920)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 18, 512)        │     4,982,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 512)            │     2,099,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 18)             │         9,234 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,099,634 (27.08 MB)
#  Trainable params: 7,099,634 (27.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Section 9 — Stratified 5-Fold Cross-Validation

# %%
skf          = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_SEED)
fold_results = []

X_tv = X_trainval[..., np.newaxis]  # add channel dim

for fold, (tr_idx, val_idx) in enumerate(skf.split(X_trainval, y_trainval), 1):
    print(f'\n── Fold {fold}/{N_FOLDS} ──')

    random.seed(RANDOM_SEED * fold)
    np.random.seed(RANDOM_SEED * fold)
    tf.random.set_seed(RANDOM_SEED * fold)

    X_tr,  X_val  = X_tv[tr_idx],      X_tv[val_idx]
    y_tr,  y_val  = y_trainval[tr_idx], y_trainval[val_idx]

    y_tr_cat  = to_categorical(y_tr,  N_CLASSES)
    y_val_cat = to_categorical(y_val, N_CLASSES)

    model = build_model(X_tr.shape[1:])
    es    = EarlyStopping(monitor='val_loss', patience=15,
                          restore_best_weights=True, verbose=0)

    model.fit(
        X_tr, y_tr_cat,
        epochs=EPOCHS, batch_size=BATCH_SIZE,
        validation_data=(X_val, y_val_cat),
        callbacks=[es], verbose=0
    )


    val_loss, val_acc_eval = model.evaluate(X_val, y_val_cat, verbose=0)
    train_loss, train_acc_eval = model.evaluate(X_tr, y_tr_cat, verbose=0)

    y_pred = np.argmax(model.predict(X_val, verbose=0), axis=1)
    f1     = f1_score(y_val, y_pred, average='macro')
    acc    = np.mean(y_pred == y_val)

    fold_results.append({
        'fold': fold,
        'val_acc': acc,
        'val_f1_macro': f1,
        'val_loss': val_loss,
        'train_loss': train_loss,
    })
    print(f'  Val Acc: {acc*100:.2f}%   Macro F1: {f1:.4f}   Val Loss: {val_loss:.4f}   Train Loss: {train_loss:.4f}')

df_folds = pd.DataFrame(fold_results)
print('\n' + '='*55)
print('  CV Summary')
print('='*55)
print(f"  Val Acc    : {df_folds['val_acc'].mean()*100:.2f}% ± {df_folds['val_acc'].std()*100:.2f}%")
print(f"  Macro F1   : {df_folds['val_f1_macro'].mean():.4f} ± {df_folds['val_f1_macro'].std():.4f}")
print(f"  Val Loss   : {df_folds['val_loss'].mean():.4f} ± {df_folds['val_loss'].std():.4f}")
print(f"  Train Loss : {df_folds['train_loss'].mean():.4f} ± {df_folds['train_loss'].std():.4f}")
print('='*55)
# Out:
# ── Fold 1/5 ──
#   Val Acc: 93.83%   Macro F1: 0.9378   Val Loss: 0.2533   Train Loss: 0.0342
#
# ── Fold 2/5 ──
#   Val Acc: 89.81%   Macro F1: 0.8978   Val Loss: 0.4201   Train Loss: 0.0198
#
# ── Fold 3/5 ──
#   Val Acc: 91.36%   Macro F1: 0.9132   Val Loss: 0.3288   Train Loss: 0.0094
#
# ── Fold 4/5 ──
#   Val Acc: 93.52%   Macro F1: 0.9355   Val Loss: 0.2583   Train Loss: 0.0236
#
# ── Fold 5/5 ──
#   Val Acc: 88.89%   Macro F1: 0.8876   Val Loss: 0.3719   Train Loss: 0.0310
#
# =======================================================
#   CV Summary
# =======================================================
#   Val Acc    : 91.48% ± 2.19%
#   Macro F1   : 0.9144 ± 0.0223
#   Val Loss   : 0.3265 ± 0.0722
#   Train Loss : 0.0236 ± 0.0098
# =======================================================

# %% [markdown]
# ## Section 10 — Train Final Model

# %%
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

X_tv_final = X_trainval[..., np.newaxis]
y_tv_cat   = to_categorical(y_trainval, N_CLASSES)

X_tf, X_vf, y_tf, y_vf = train_test_split(
    X_tv_final, y_tv_cat, test_size=0.1,
    random_state=RANDOM_SEED, stratify=y_trainval
)

final_model = build_model(X_tf.shape[1:])
es_final    = EarlyStopping(monitor='val_loss', patience=15,
                             restore_best_weights=True, verbose=1)

history = final_model.fit(
    X_tf, y_tf,
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    validation_data=(X_vf, y_vf),
    callbacks=[es_final], verbose=1
)
print('Final model trained.')
# Out:
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.2963 - loss: 1.8918 - val_accuracy: 0.4753 - val_loss: 1.2181
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5048 - loss: 1.2040 - val_accuracy: 0.6667 - val_loss: 0.8819
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6557 - loss: 0.9873 - val_accuracy: 0.6975 - val_loss: 0.7979
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7311 - loss: 0.7650 - val_accuracy: 0.7593 - val_loss: 0.7457
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7147 - loss: 0.7729 - val_accuracy: 0.7778 - val_loss: 0.6429
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8128 - loss: 0.5693 - val_accuracy: 0.7654 - val_loss: 0.6904
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8128 - loss: 0.5739 - val_accuracy: 0.8272 - val_loss: 0.5870
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8299 - loss: 0.4959 - val_accuracy: 0.8333 - val_loss: 0.5162
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8429 - loss: 0.4748 - val_accuracy: 0.8333 - val_loss: 0.5440
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8628 - loss: 0.4211 - val_accuracy: 0.8642 - val_loss: 0.4039
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8724 - loss: 0.3868 - val_accuracy: 0.8457 - val_loss: 0.5226
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8930 - loss: 0.3535 - val_accuracy: 0.8457 - val_loss: 0.4438
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8964 - loss: 0.3180 - val_accuracy: 0.8642 - val_loss: 0.4154
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8834 - loss: 0.3620 - val_accuracy: 0.9074 - val_loss: 0.3683
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9136 - loss: 0.2669 - val_accuracy: 0.9136 - val_loss: 0.2909
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9191 - loss: 0.2518 - val_accuracy: 0.8827 - val_loss: 0.3703
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9143 - loss: 0.2564 - val_accuracy: 0.9074 - val_loss: 0.2702
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9300 - loss: 0.2165 - val_accuracy: 0.9259 - val_loss: 0.2760
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9280 - loss: 0.2265 - val_accuracy: 0.9136 - val_loss: 0.2828
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9410 - loss: 0.1834 - val_accuracy: 0.9198 - val_loss: 0.3088
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9506 - loss: 0.1523 - val_accuracy: 0.9136 - val_loss: 0.3197
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9588 - loss: 0.1410 - val_accuracy: 0.9136 - val_loss: 0.3667
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9554 - loss: 0.1213 - val_accuracy: 0.9136 - val_loss: 0.3740
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9623 - loss: 0.1255 - val_accuracy: 0.9074 - val_loss: 0.4005
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9630 - loss: 0.1296 - val_accuracy: 0.9198 - val_loss: 0.2523
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9595 - loss: 0.1225 - val_accuracy: 0.9012 - val_loss: 0.4265
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9588 - loss: 0.1132 - val_accuracy: 0.8889 - val_loss: 0.4009
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9486 - loss: 0.1666 - val_accuracy: 0.9136 - val_loss: 0.2717
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9657 - loss: 0.1138 - val_accuracy: 0.9321 - val_loss: 0.3267
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9650 - loss: 0.1148 - val_accuracy: 0.9136 - val_loss: 0.2639
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9739 - loss: 0.0938 - val_accuracy: 0.9321 - val_loss: 0.3393
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9760 - loss: 0.0754 - val_accuracy: 0.9074 - val_loss: 0.3579
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9760 - loss: 0.0762 - val_accuracy: 0.9383 - val_loss: 0.2611
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9698 - loss: 0.0909 - val_accuracy: 0.9198 - val_loss: 0.3309
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9801 - loss: 0.0705 - val_accuracy: 0.9198 - val_loss: 0.3197
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9746 - loss: 0.0900 - val_accuracy: 0.9259 - val_loss: 0.3159
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9787 - loss: 0.0637 - val_accuracy: 0.9383 - val_loss: 0.3439
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9774 - loss: 0.0737 - val_accuracy: 0.9259 - val_loss: 0.3155
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9726 - loss: 0.0872 - val_accuracy: 0.9259 - val_loss: 0.3233
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9726 - loss: 0.0983 - val_accuracy: 0.9321 - val_loss: 0.2313
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9712 - loss: 0.0844 - val_accuracy: 0.9198 - val_loss: 0.2998
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9801 - loss: 0.0565 - val_accuracy: 0.9259 - val_loss: 0.3439
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9726 - loss: 0.0808 - val_accuracy: 0.9321 - val_loss: 0.3069
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9883 - loss: 0.0333 - val_accuracy: 0.9136 - val_loss: 0.3522
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9904 - loss: 0.0391 - val_accuracy: 0.9506 - val_loss: 0.2239
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9842 - loss: 0.0498 - val_accuracy: 0.9074 - val_loss: 0.3561
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9829 - loss: 0.0548 - val_accuracy: 0.9383 - val_loss: 0.3204
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9835 - loss: 0.0528 - val_accuracy: 0.9321 - val_loss: 0.2744
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9739 - loss: 0.0908 - val_accuracy: 0.9383 - val_loss: 0.3063
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9760 - loss: 0.0831 - val_accuracy: 0.9383 - val_loss: 0.2359
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9822 - loss: 0.0555 - val_accuracy: 0.9383 - val_loss: 0.2555
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9877 - loss: 0.0394 - val_accuracy: 0.9383 - val_loss: 0.3143
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9904 - loss: 0.0270 - val_accuracy: 0.9259 - val_loss: 0.3442
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9787 - loss: 0.0722 - val_accuracy: 0.9568 - val_loss: 0.2706
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9842 - loss: 0.0581 - val_accuracy: 0.9568 - val_loss: 0.1607
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9835 - loss: 0.0480 - val_accuracy: 0.9383 - val_loss: 0.3836
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9781 - loss: 0.0569 - val_accuracy: 0.9321 - val_loss: 0.3194
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9842 - loss: 0.0526 - val_accuracy: 0.9259 - val_loss: 0.2843
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9897 - loss: 0.0308 - val_accuracy: 0.9383 - val_loss: 0.2449
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9938 - loss: 0.0267 - val_accuracy: 0.9383 - val_loss: 0.4151
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9835 - loss: 0.0564 - val_accuracy: 0.9136 - val_loss: 0.3750
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9883 - loss: 0.0391 - val_accuracy: 0.9321 - val_loss: 0.3415
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9911 - loss: 0.0320 - val_accuracy: 0.9198 - val_loss: 0.5209
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9883 - loss: 0.0397 - val_accuracy: 0.9383 - val_loss: 0.3623
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9870 - loss: 0.0476 - val_accuracy: 0.9568 - val_loss: 0.2576
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9890 - loss: 0.0370 - val_accuracy: 0.9506 - val_loss: 0.2848
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9931 - loss: 0.0307 - val_accuracy: 0.9259 - val_loss: 0.3252
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9890 - loss: 0.0410 - val_accuracy: 0.9506 - val_loss: 0.2885
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9918 - loss: 0.0227 - val_accuracy: 0.9568 - val_loss: 0.2140
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9890 - loss: 0.0391 - val_accuracy: 0.9383 - val_loss: 0.3047
# Epoch 70: early stopping
# Restoring model weights from the end of the best epoch: 55.
# Final model trained.

# %% [markdown]
# ## Section 11 — Evaluate on Held-Out Test Set

# %%
X_te        = X_test[..., np.newaxis]
y_pred_test = np.argmax(final_model.predict(X_te, verbose=0), axis=1)

test_acc = np.mean(y_pred_test == y_test)
test_f1  = f1_score(y_test, y_pred_test, average='macro')

print('='*45)
print('  FINAL TEST RESULTS (CNN+LSTM + MFCC)')
print('='*45)
print(f'  Test Accuracy : {test_acc*100:.2f}%')
print(f'  Macro F1      : {test_f1:.4f}')
print('='*45)
print('\nClassification Report:')
print(classification_report(y_test, y_pred_test, target_names=VOWEL_LABELS))
# Out:
# =============================================
#   FINAL TEST RESULTS (CNN+LSTM + MFCC)
# =============================================
#   Test Accuracy : 92.22%
#   Macro F1      : 0.9227
# =============================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           อา       0.91      1.00      0.95        10
#           อี       1.00      0.90      0.95        10
#          อือ       0.77      1.00      0.87        10
#           อู       1.00      0.90      0.95        10
#           เอ       0.83      1.00      0.91        10
#           แอ       1.00      1.00      1.00        10
#           โอ       0.89      0.80      0.84        10
#           ออ       0.90      0.90      0.90        10
#          เออ       1.00      0.90      0.95        10
#           อะ       1.00      0.90      0.95        10
#           อิ       0.91      1.00      0.95        10
#           อึ       1.00      1.00      1.00        10
#           อุ       1.00      0.90      0.95        10
#          เอะ       0.78      0.70      0.74        10
#          แอะ       1.00      1.00      1.00        10
#          โอะ       0.73      0.80      0.76        10
#         เอาะ       1.00      0.90      0.95        10
#         เออะ       1.00      1.00      1.00        10
#
#     accuracy                           0.92       180
#    macro avg       0.93      0.92      0.92       180
# weighted avg       0.93      0.92      0.92       180

# %% [markdown]
# ## Section 12 — Confusion Matrix

# %%
# ── Thai font setup ─────────────────────────────────────────
urllib.request.urlretrieve(
    'https://github.com/google/fonts/raw/main/ofl/sarabun/Sarabun-Regular.ttf',
    '/content/Sarabun-Regular.ttf'
)
fm.fontManager.addfont('/content/Sarabun-Regular.ttf')
plt.rcParams['font.family'] = 'Sarabun'
print('Thai font loaded.')
# Out:
# Thai font loaded.

# %%
cm = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples',
            xticklabels=VOWEL_LABELS, yticklabels=VOWEL_LABELS)
plt.title('Confusion Matrix — CNN+LSTM + MFCC', fontsize=14)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/exp_cnnlstm_mfcc_cm.png', dpi=150)
plt.show()

# %% [markdown]
# ## Section 13 — Training Curve

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(history.history['accuracy'],     label='Train')
axes[0].plot(history.history['val_accuracy'], label='Val')
axes[0].set_title('Accuracy')
axes[0].legend()

axes[1].plot(history.history['loss'],     label='Train')
axes[1].plot(history.history['val_loss'], label='Val')
axes[1].set_title('Loss')
axes[1].legend()

plt.suptitle('Training Curve — CNN+LSTM + MFCC')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/exp_cnnlstm_mfcc_curve.png', dpi=150)
plt.show()

# %% [markdown]
# ## Section 14 — Save Model & Results

# %%
print('\n── For comparison table ──')
print(f"CNN+LSTM + MFCC | CV F1: {df_folds['val_f1_macro'].mean():.4f}±{df_folds['val_f1_macro'].std():.4f} | Test F1: {test_f1:.4f} | Test Acc: {test_acc*100:.2f}%")
# Out:
# ── For comparison table ──
# CNN+LSTM + MFCC | CV F1: 0.9144±0.0223 | Test F1: 0.9227 | Test Acc: 92.22%
